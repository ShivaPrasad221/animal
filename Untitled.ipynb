# %%
from ultralytics import YOLO
import cv2
import os
from pathlib import Path

# %%
# Set dataset directory path
dataset_dir = "D:/SHIVAA/CODES/ANIMAL"

# Example structure
train_images = os.path.join(dataset_dir, "train/images")
val_images = os.path.join(dataset_dir, "valid/images")
train_labels = os.path.join(dataset_dir, "train/labels")
val_labels = os.path.join(dataset_dir, "valid/labels")

# %%
# Create the YAML file for the dataset
yaml_content = """
path: D:/SHIVAA/CODES/ANIMAL
train: D:/SHIVAA/CODES/ANIMAL/train
val: D:/SHIVAA/CODES/ANIMAL/valid

nc: 15
names: ['Bear', 'Brown-bear', 'Bull', 'Cheetah', 'Crocodile', 'Elephant', 'Fox', 'Hippopotamus', 'Jaguar', 'Leopard', 'Lion', 'Panda', 'Pig', 'Rhinoceros', 'Tiger']

"""

# Save the YAML file
with open("data.yaml", "w") as f:
    f.write(yaml_content)

# %%
# Initialize YOLOv8 model (e.g., yolov8n for Nano version)
model = YOLO('yolov8n.pt')  # Or load a pretrained model like 'yolov8n.pt'

# %%
# Train the YOLOv8 model
model.train(data='data.yaml', epochs=10, imgsz=640, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.48 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.38  Python-3.9.12 torch-2.5.1+cpu CPU (Intel Core(TM) i5-6500 3.20GHz)
# ...

# %%
# Evaluate the trained model on validation data
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.38  Python-3.9.12 torch-2.5.1+cpu CPU (Intel Core(TM) i5-6500 3.20GHz)
# Model summary (fused): 168 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\SHIVAA\CODES\ANIMAL\valid\labels.cache... 250 images, 0 backgrounds, 0 corrupt: 100%|██████████| 250/2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:30
#                    all        250        281      0.741      0.708      0.803       0.65
#                   Bear         39         42      0.621      0.571      0.591      0.502
#             Brown-bear         39         44      0.629      0.888      0.789      0.716
#                   Bull         73         91      0.921      0.512      0.713      0.557
#                Cheetah         20         20      0.937       0.45      0.904      0.743
#              Crocodile         71         75      0.899      0.828      0.897      0.606
# ...

# %%
model_path = 'D:/SHIVAA/CODES/ANIMAL/runs/detect/train2/weights/best.pt'
model = YOLO(model_path)
results = model(source='D:/SHIVAA/CODES/ANIMAL/test/images', conf=0.25,save=True)
# Out:
# image 1/499 D:\SHIVAA\CODES\ANIMAL\test\images\007de825130c594c_jpg.rf.7326e5c318ee96c11a7d99d60ba7f920.jpg: 640x640 1 Fox, 104.3ms
# image 2/499 D:\SHIVAA\CODES\ANIMAL\test\images\0149d723dbc0d724_jpg.rf.adca75966ffce225e1283bea4242cb79.jpg: 640x640 1 Lion, 81.9ms
# image 3/499 D:\SHIVAA\CODES\ANIMAL\test\images\0195d3043a0ca861_jpg.rf.03205c2ca72fecf00e2375351d02b838.jpg: 640x640 1 Brown-bear, 90.7ms
# image 4/499 D:\SHIVAA\CODES\ANIMAL\test\images\01981fb00cd5d947_jpg.rf.a3f5379712f51489c59f5119137ffb82.jpg: 640x640 1 Crocodile, 102.1ms
# image 5/499 D:\SHIVAA\CODES\ANIMAL\test\images\028f8db193a85ecf_jpg.rf.6cf99feaaf7c203553b39a4ec43cab7b.jpg: 640x640 1 Elephant, 105.8ms
# image 6/499 D:\SHIVAA\CODES\ANIMAL\test\images\032026a9f3bfd4fa_jpg.rf.1c951023e069b9920ef4c642cb1a01e8.jpg: 640x640 1 Crocodile, 125.4ms
# image 7/499 D:\SHIVAA\CODES\ANIMAL\test\images\03b9630d0ba5749d_jpg.rf.88a464f28fcd7159e3cfbcab9ebe82d0.jpg: 640x640 1 Lion, 99.4ms
# ...

# %%
# !pip install ultralytics
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\main python\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\main python\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\main python\anaconda3\lib\site-packages)

# %%
# Export the trained model
model.export(format='onnx')  # Export to ONNX format
# Out:
# Ultralytics 8.3.38  Python-3.9.12 torch-2.5.1+cpu CPU (Intel Core(TM) i5-6500 3.20GHz)
#
# PyTorch: starting from 'D:\SHIVAA\CODES\ANIMAL\runs\detect\train2\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 19, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnxslim'] not found, attempting AutoUpdate...
# ...
#
# requirements: AutoUpdate success  3.3s, installed 1 package: ['onnxslim']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.43...
# ONNX: export success  4.9s, saved as 'D:\SHIVAA\CODES\ANIMAL\runs\detect\train2\weights\best.onnx' (11.7 MB)
#
# Export complete (5.3s)
# Results saved to D:\SHIVAA\CODES\ANIMAL\runs\detect\train2\weights
# Predict:         yolo predict task=detect model=D:\SHIVAA\CODES\ANIMAL\runs\detect\train2\weights\best.onnx imgsz=640
# ...

# %%
# !pip install opencv-contrib-python
# Out:
# ...
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\main python\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\main python\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Main Python\\anaconda3\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
#Image code


from ultralytics import YOLO
import cv2

# Load YOLO model
model = YOLO(r'D:/SHIVAA/CODES/ANIMAL/runs/detect/train2/weights/best.pt')

# Input and output image paths
input_image_path = r"D:/SHIVAA/CODES/ANIMAL/test/images/0af88c7a8b7195c7_jpg.rf.255445ee28f4780a4458cda1489fccc8.jpg"
output_image_path = r"D:/SHIVAA/CODES/ANIMAL/output.jpg"

# Load the image
image = cv2.imread(input_image_path)

# Perform detection
results = model.predict(image)

# Annotate detections
for result in results[0].boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))  # Bounding box coordinates
    label = f"{model.names[int(cls)]} {conf:.2f}"  # Label with confidence

    # Draw bounding box and label
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
    cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Save the output image
cv2.imwrite(output_image_path, image)
# Out:
# 0: 640x640 1 Leopard, 100.2ms
# Speed: 12.8ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# True
